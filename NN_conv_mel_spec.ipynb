# %%
import copy
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import keras
from keras.layers import Dense, Flatten, Dropout, LocallyConnected2D
from sklearn.metrics import roc_curve
import tensorflow as tf
import os

# %% [markdown]
# # Loading data

# %%
# Parameters
fs = 44100                  # Hz, sampling frequency
f_size = 512                # Frame size
h_size = int(f_size/2)      # Hop size
supra_frame_duration = 0.5  # seconds
frame_num_gl = round(supra_frame_duration / (h_size/fs))
n_mel = 64
dir_HC = 'wav'+ os.sep + 'HC' + os.sep
dir_ALS = 'wav' + os.sep + 'ALS' + os.sep
directory_ALS = os.listdir(dir_ALS)
directory_HC = os.listdir(dir_HC)

# %%
X = np.zeros((20000,n_mel,frame_num_gl))    # data
y = np.zeros((20000,1))                     # labels
X_global_index = 0
X_ids = list([])                            # IDs of the speakers
# Cycle for HC (helthy controls)
for i in range(len(directory_HC)):
    if directory_HC[i][-9:]=='a_mel.dat':
        fileName = dir_HC + directory_HC[i]
        
        # print(fileName)

        X_spec = np.fromfile(dir_HC + directory_HC[i], dtype=np.half)
        X_spec = np.reshape(X_spec,(n_mel, np.floor(len(X_spec)/n_mel).astype(int)))
        
        # plt.subplots(dpi=150)
        # plt.pcolor(X_spec,shading='flat',cmap='jet')
        # plt.xlabel('Номер фрейма')
        # plt.ylabel('$\log(|X(k,m)|)$')
        # plt.show()

#       #Запись фрагметов спектра в трехмерный массив 
        frame_num = X_spec.shape[1]
        N_supra_frames = frame_num - frame_num_gl + 1

        # generator comprehension
        gen_range = (n * 2 for n in range(0, np.floor(N_supra_frames/2).astype(int)))
        for n in gen_range:
            X[X_global_index,:,:] = X_spec[:,n:n+frame_num_gl]
            X_ids.append(int(directory_HC[i][0:3]))
            y[X_global_index] = 0
            X_global_index = X_global_index +1
    
# Cycle for ALS (pathology)
for i in range(len(directory_ALS)):
    if directory_ALS[i][-9:]=='a_mel.dat':
        fileName = dir_ALS + directory_ALS[i]        

        # print(fileName)

        X_spec = np.fromfile(dir_ALS + directory_ALS[i], dtype=np.half)
        X_spec = np.reshape(X_spec,(n_mel, np.floor(len(X_spec)/n_mel).astype(int)))

#       #Запись фрагметов спектра в трехмерный массив
        frame_num = X_spec.shape[1]
        N_supra_frames = frame_num - frame_num_gl + 1

        # generator comprehension
        gen_range = (n * 2 for n in range(0, np.floor(N_supra_frames/2).astype(int)))
        for n in gen_range:
            X[X_global_index,:,:] = X_spec[:,n:n+frame_num_gl]
            X_ids.append(int(directory_ALS[i][0:3]))
            y[X_global_index] = 1
            X_global_index = X_global_index + 1
            
inds_to_delete = np.array(range(y.shape[0]))>=X_global_index
y = np.delete(y,inds_to_delete)
X = np.delete(X,inds_to_delete, axis=0)

# %% [markdown]
# # Data normalization

# %%
X_mean = tf.reduce_mean(X, axis = 0).numpy()
X_zero_mean = X - X_mean
X_sd   = np.sqrt(tf.reduce_mean((X_zero_mean)**2, axis = 0).numpy())
# X_sd = np.sqrt(X_sd.reshape(X.shape[0],1))

print('mean(X[2,:]) = ', X_mean[0])
print('SD(X[2,:]) = ', X_sd[0])

# X_normalized = keras.layers.UnitNormalization(axis=1)(X)
# X_normalized = X_normalized.numpy()

X_normalized = (X_zero_mean)/X_sd

# print('mean(X_normalized[2,:]) = ', np.mean(X_normalized[:,:,2]))
# print('SD(X_normalized[2,:]) = ', np.std(X_normalized[:,:,0]))
# Out:
# mean(X[2,:]) =  [-35.8262778  -35.85557905 -35.83792167 -35.86602345 -35.84714869
#  -35.8790972  -35.85516558 -35.8916828  -35.86320764 -35.90192537
#  -35.86851028 -35.90863185 -35.88083687 -35.91569122 -35.89347623
#  -35.92152638 -35.90267594 -35.93181931 -35.91274527 -35.94708844
#  -35.92294048 -35.95809907 -35.93561269 -35.96967722 -35.94698005
#  -35.98083891 -35.9602471  -35.98950397 -35.97157307 -36.00059056
#  -35.98394019 -36.01328539 -35.9942425  -36.02360818 -36.00514561
#  -36.03583108 -36.01169635 -36.04410698 -36.02135732 -36.05080195
#  -36.0323957  -36.05788905 -36.04422134 -36.06721848 -36.051963
#  -36.07886192 -36.06115845 -36.08985548 -36.07033085 -36.0994627
#  -36.08115032 -36.10709513 -36.09474422 -36.11916868 -36.1038364
#  -36.13082279 -36.11679621 -36.1440574  -36.12505718 -36.15511838
#  -36.13410328 -36.16420545 -36.14582352 -36.17370811 -36.15488327
#  -36.18253617 -36.16601082 -36.19223469 -36.17565644 -36.20557129
#  -36.18437654 -36.21622349 -36.1928389  -36.22834142 -36.20220759
#  -36.23834334 -36.2121839  -36.24587763 -36.22108534 -36.25428879
#  -36.22972991 -36.26591985 -36.23978858 -36.27632116 -36.24967528
#  -36.28567192]
# SD(X[2,:]) =  [12.9483437  13.03275488 12.95553151 13.04316129 12.95880021 13.05046723
#  12.95724525 13.05749266 12.95763216 13.06268638 12.95580777 13.06315668
#  12.96230297 13.06425983 12.96913974 13.06336654 12.97159712 13.06676248
#  12.9775856  13.07884626 12.98416105 13.08454495 12.99306758 13.09133054
#  12.99904193 13.0990602  13.00676621 13.10269313 13.01049735 13.11232214
#  13.01486902 13.11832645 13.01619938 13.12207722 13.02022759 13.12782584
#  13.01859785 13.13061604 13.01955298 13.13423036 13.02348265 13.13647566
#  13.02981885 13.14067717 13.03132691 13.14532467 13.03857966 13.14990475
#  13.04242421 13.15291127 13.0471881  13.15439691 13.05713006 13.16077189
#  13.06075951 13.16660183 13.07293504 13.17522664 13.07565602 13.18119517
#  13.07934879 13.18629677 13.08660684 13.18949147 13.08827713 13.19149861
#  13.09338336 13.19497697 13.09908982 13.20106513 13.1048401  13.20552984
#  13.10991164 13.21119996 13.11431895 13.21515987 13.12220842 13.21601964
#  13.12763759 13.21837824 13.13120736 13.2244043  13.13638004 13.22966592
#  13.14264287 13.23250514]

# %% [markdown]
# # Train/Test sets

# %%
test_subjects_ids = (25, 26, 32, 61, 62, 107) # 3 -> ALS;  3-> HC

test_inds_in_dataset = (i for i in range(len(X_ids)) if X_ids[i] in test_subjects_ids)
test_inds_in_dataset = list(test_inds_in_dataset)

train_inds_in_dataset = (i for i in range(len(X_ids)) if (X_ids[i] not in test_subjects_ids))
train_inds_in_dataset = list(train_inds_in_dataset)

X_test  = X_normalized[test_inds_in_dataset,:,:]
y_test  = y[test_inds_in_dataset]

X_train = X_normalized[train_inds_in_dataset,:,:]
y_train = y[train_inds_in_dataset]

# %%
# (x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# отображение первых 25 изображений из обучающей выборки
f, a = plt.subplots(3, 3, figsize=(14,6))
f.suptitle('Примеры 9 (нормализованных) спетрограмм из обучающей выборки')
for i in range(9):
    plt.subplot(3,3,i+1)
    # plt.xticks([])
    # plt.yticks([])
    # plt.imshow(X_train[i], cmap='jet')
    plt.pcolor(X_train[i+200], cmap='jet')

plt.show()

# %%
# for tanh activation
# y_test[y_test==-1] = 0
# y_train[y_train==-1] = 0

# %%
nidden_neuron_num = 3
model = keras.Sequential([
#    Flatten(input_shape=(X.shape[1], X.shape[2])),
    LocallyConnected1D(filters=nidden_neuron_num, kernel_size=(n_mel), strides=10, 
                    kernel_regularizer=keras.regularizers.L1(0.1),
                    activation='relu',
                    kernel_initializer=keras.initializers.HeNormal(seed=2),
                    input_shape=X_mean.shape),
    # Dropout(0.5),
    Flatten(),
    Dense(1, 
        activation='sigmoid',
        kernel_regularizer=keras.regularizers.L1(0.1),
        kernel_initializer=keras.initializers.GlorotNormal(seed=1))
])

print(model.summary())      # вывод структуры НС в консоль

lr_schedule = keras.optimizers.schedules.learning_rate_schedule.ExponentialDecay(
    initial_learning_rate = 5e-3,
    decay_steps=1000,
    decay_rate=0.9)
my_optimizer = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

model.compile(optimizer=my_optimizer,
            #  optimizer='adam', # bad choice
             # loss='mean_squared_error',
             loss=keras.losses.BinaryCrossentropy(from_logits=False),
             metrics=['accuracy', keras.metrics.Precision(), 
             keras.metrics.Recall()])
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  locally_connected1d_14 (Loc  (None, 1, 3)             16515
#  allyConnected1D)
#
#  flatten_8 (Flatten)         (None, 3)                 0
#
#  dense_13 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 16,519
# Trainable params: 16,519
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train process

# %%
# X_tr = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2]))
epochs_num = 150
# y_train = y_train.reshape((len(y_train),1,1))
# y_train = y_train.reshape((y_train.shape[0]))
hist = model.fit(X_train, y_train, batch_size=200, epochs=epochs_num, validation_split=0.3)
# Out:
# Epoch 1/150
# 56/56 [==============================] - 1s 13ms/step - loss: 6.5980 - accuracy: 0.8056 - precision_15: 0.8634 - recall_13: 0.4365 - val_loss: 2.4357 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 2/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.8453 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.4434 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 3/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.7764 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.5916 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 4/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.7131 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.5516 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 5/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.7043 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.5386 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 6/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6628 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.7151 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 7/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6872 - accuracy: 0.6927 - precision_15: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 2.6023 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 8/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.6232 - accuracy: 0.7104 - precision_15: 0.9261 - recall_13: 0.0626 - val_loss: 2.8662 - val_accuracy: 0.2586 - val_precision_15: 1.0000 - val_recall_13: 0.2586
# Epoch 9/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6426 - accuracy: 0.8106 - precision_15: 0.9240 - recall_13: 0.4183 - val_loss: 2.6873 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 10/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6034 - accuracy: 0.8219 - precision_15: 0.9748 - recall_13: 0.4318 - val_loss: 2.6268 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 11/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5890 - accuracy: 0.8207 - precision_15: 0.9739 - recall_13: 0.4280 - val_loss: 2.6823 - val_accuracy: 0.0137 - val_precision_15: 1.0000 - val_recall_13: 0.0137
# Epoch 12/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6224 - accuracy: 0.8312 - precision_15: 0.9323 - recall_13: 0.4859 - val_loss: 2.5194 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 13/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.5645 - accuracy: 0.8346 - precision_15: 0.9684 - recall_13: 0.4774 - val_loss: 3.1743 - val_accuracy: 0.1497 - val_precision_15: 1.0000 - val_recall_13: 0.1497
# Epoch 14/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6402 - accuracy: 0.8359 - precision_15: 0.9029 - recall_13: 0.5223 - val_loss: 2.7555 - val_accuracy: 0.0999 - val_precision_15: 1.0000 - val_recall_13: 0.0999
# Epoch 15/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.5731 - accuracy: 0.8361 - precision_15: 0.9611 - recall_13: 0.4865 - val_loss: 2.9029 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 16/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5908 - accuracy: 0.8354 - precision_15: 0.9202 - recall_13: 0.5085 - val_loss: 2.7215 - val_accuracy: 2.1079e-04 - val_precision_15: 1.0000 - val_recall_13: 2.1079e-04
# Epoch 17/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6120 - accuracy: 0.8414 - precision_15: 0.8964 - recall_13: 0.5470 - val_loss: 2.7120 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 18/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5278 - accuracy: 0.8452 - precision_15: 0.9862 - recall_13: 0.5032 - val_loss: 2.9022 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 19/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5568 - accuracy: 0.8481 - precision_15: 0.9442 - recall_13: 0.5376 - val_loss: 2.7464 - val_accuracy: 0.1381 - val_precision_15: 1.0000 - val_recall_13: 0.1381
# Epoch 20/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5302 - accuracy: 0.8501 - precision_15: 0.9570 - recall_13: 0.5364 - val_loss: 3.1710 - val_accuracy: 0.0112 - val_precision_15: 1.0000 - val_recall_13: 0.0112
# Epoch 21/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5055 - accuracy: 0.8568 - precision_15: 0.9638 - recall_13: 0.5550 - val_loss: 2.9268 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 22/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5168 - accuracy: 0.8524 - precision_15: 0.9662 - recall_13: 0.5385 - val_loss: 2.7307 - val_accuracy: 0.0987 - val_precision_15: 1.0000 - val_recall_13: 0.0987
# Epoch 23/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5219 - accuracy: 0.8563 - precision_15: 0.9580 - recall_13: 0.5567 - val_loss: 2.9256 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 24/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4854 - accuracy: 0.8658 - precision_15: 0.9729 - recall_13: 0.5794 - val_loss: 3.2478 - val_accuracy: 0.1271 - val_precision_15: 1.0000 - val_recall_13: 0.1271
# Epoch 25/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5454 - accuracy: 0.8686 - precision_15: 0.9223 - recall_13: 0.6249 - val_loss: 2.8210 - val_accuracy: 0.0426 - val_precision_15: 1.0000 - val_recall_13: 0.0426
# Epoch 26/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4989 - accuracy: 0.8597 - precision_15: 0.9521 - recall_13: 0.5723 - val_loss: 2.9599 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 27/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.5747 - accuracy: 0.8425 - precision_15: 0.8446 - recall_13: 0.5976 - val_loss: 3.1073 - val_accuracy: 0.2572 - val_precision_15: 1.0000 - val_recall_13: 0.2572
# Epoch 28/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4924 - accuracy: 0.8634 - precision_15: 0.9449 - recall_13: 0.5899 - val_loss: 2.7072 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 29/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4564 - accuracy: 0.8669 - precision_15: 0.9726 - recall_13: 0.5835 - val_loss: 2.8141 - val_accuracy: 0.1033 - val_precision_15: 1.0000 - val_recall_13: 0.1033
# Epoch 30/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4589 - accuracy: 0.8630 - precision_15: 0.9591 - recall_13: 0.5788 - val_loss: 3.1862 - val_accuracy: 0.1145 - val_precision_15: 1.0000 - val_recall_13: 0.1145
# Epoch 31/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4612 - accuracy: 0.8699 - precision_15: 0.9563 - recall_13: 0.6044 - val_loss: 3.0122 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 32/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4855 - accuracy: 0.8659 - precision_15: 0.9236 - recall_13: 0.6146 - val_loss: 2.9446 - val_accuracy: 0.1202 - val_precision_15: 1.0000 - val_recall_13: 0.1202
# Epoch 33/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.4578 - accuracy: 0.8673 - precision_15: 0.9502 - recall_13: 0.5996 - val_loss: 2.7431 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 34/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4162 - accuracy: 0.8648 - precision_15: 0.9867 - recall_13: 0.5679 - val_loss: 3.2855 - val_accuracy: 0.1155 - val_precision_15: 1.0000 - val_recall_13: 0.1155
# Epoch 35/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.6172 - accuracy: 0.8340 - precision_15: 0.7952 - recall_13: 0.6196 - val_loss: 2.8745 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 36/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4073 - accuracy: 0.8711 - precision_15: 0.9843 - recall_13: 0.5899 - val_loss: 2.9810 - val_accuracy: 0.0854 - val_precision_15: 1.0000 - val_recall_13: 0.0854
# Epoch 37/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4576 - accuracy: 0.8604 - precision_15: 0.9219 - recall_13: 0.5964 - val_loss: 2.8747 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 38/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4003 - accuracy: 0.8729 - precision_15: 0.9780 - recall_13: 0.5999 - val_loss: 3.1558 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 39/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4352 - accuracy: 0.8583 - precision_15: 0.9269 - recall_13: 0.5850 - val_loss: 2.8783 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 40/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4406 - accuracy: 0.8658 - precision_15: 0.9155 - recall_13: 0.6208 - val_loss: 2.9466 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 41/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4197 - accuracy: 0.8699 - precision_15: 0.9337 - recall_13: 0.6208 - val_loss: 2.8188 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 42/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3667 - accuracy: 0.8767 - precision_15: 0.9820 - recall_13: 0.6099 - val_loss: 3.0480 - val_accuracy: 0.0285 - val_precision_15: 1.0000 - val_recall_13: 0.0285
# Epoch 43/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4123 - accuracy: 0.8738 - precision_15: 0.9567 - recall_13: 0.6173 - val_loss: 3.0038 - val_accuracy: 0.1425 - val_precision_15: 1.0000 - val_recall_13: 0.1425
# Epoch 44/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3529 - accuracy: 0.8901 - precision_15: 0.9866 - recall_13: 0.6514 - val_loss: 3.1222 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 45/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3636 - accuracy: 0.8781 - precision_15: 0.9668 - recall_13: 0.6249 - val_loss: 3.3049 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 46/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3650 - accuracy: 0.8863 - precision_15: 0.9807 - recall_13: 0.6429 - val_loss: 2.8498 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 47/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3884 - accuracy: 0.8739 - precision_15: 0.9502 - recall_13: 0.6223 - val_loss: 2.8859 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 48/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3785 - accuracy: 0.8665 - precision_15: 0.9470 - recall_13: 0.5991 - val_loss: 2.9663 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 49/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3689 - accuracy: 0.8784 - precision_15: 0.9489 - recall_13: 0.6387 - val_loss: 3.0499 - val_accuracy: 0.1258 - val_precision_15: 1.0000 - val_recall_13: 0.1258
# Epoch 50/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.4245 - accuracy: 0.8652 - precision_15: 0.8892 - recall_13: 0.6414 - val_loss: 2.6726 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 51/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3384 - accuracy: 0.8880 - precision_15: 0.9835 - recall_13: 0.6464 - val_loss: 2.8286 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 52/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3443 - accuracy: 0.8746 - precision_15: 0.9500 - recall_13: 0.6249 - val_loss: 2.9135 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 53/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3338 - accuracy: 0.8802 - precision_15: 0.9659 - recall_13: 0.6326 - val_loss: 2.8591 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 54/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3278 - accuracy: 0.8913 - precision_15: 0.9762 - recall_13: 0.6626 - val_loss: 3.0370 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 55/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3492 - accuracy: 0.8784 - precision_15: 0.9545 - recall_13: 0.6346 - val_loss: 3.0337 - val_accuracy: 0.0059 - val_precision_15: 1.0000 - val_recall_13: 0.0059
# Epoch 56/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2847 - accuracy: 0.8930 - precision_15: 0.9973 - recall_13: 0.6537 - val_loss: 2.8768 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 57/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2996 - accuracy: 0.8941 - precision_15: 0.9903 - recall_13: 0.6620 - val_loss: 3.0420 - val_accuracy: 0.0339 - val_precision_15: 1.0000 - val_recall_13: 0.0339
# Epoch 58/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3434 - accuracy: 0.8766 - precision_15: 0.9306 - recall_13: 0.6467 - val_loss: 2.9459 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 59/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2972 - accuracy: 0.8863 - precision_15: 0.9803 - recall_13: 0.6429 - val_loss: 2.9048 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 60/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2828 - accuracy: 0.8939 - precision_15: 0.9882 - recall_13: 0.6628 - val_loss: 3.1517 - val_accuracy: 0.1581 - val_precision_15: 1.0000 - val_recall_13: 0.1581
# Epoch 61/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2883 - accuracy: 0.8876 - precision_15: 0.9821 - recall_13: 0.6461 - val_loss: 3.2328 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 62/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3119 - accuracy: 0.8808 - precision_15: 0.9419 - recall_13: 0.6526 - val_loss: 3.0884 - val_accuracy: 0.1454 - val_precision_15: 1.0000 - val_recall_13: 0.1454
# Epoch 63/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2944 - accuracy: 0.8886 - precision_15: 0.9641 - recall_13: 0.6623 - val_loss: 3.0550 - val_accuracy: 0.0011 - val_precision_15: 1.0000 - val_recall_13: 0.0011
# Epoch 64/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2673 - accuracy: 0.9012 - precision_15: 0.9894 - recall_13: 0.6858 - val_loss: 2.8804 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 65/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3019 - accuracy: 0.8727 - precision_15: 0.9331 - recall_13: 0.6311 - val_loss: 3.1829 - val_accuracy: 0.1315 - val_precision_15: 1.0000 - val_recall_13: 0.1315
# Epoch 66/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3268 - accuracy: 0.8754 - precision_15: 0.9209 - recall_13: 0.6505 - val_loss: 3.0301 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 67/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.2501 - accuracy: 0.8927 - precision_15: 0.9929 - recall_13: 0.6555 - val_loss: 3.0494 - val_accuracy: 0.1191 - val_precision_15: 1.0000 - val_recall_13: 0.1191
# Epoch 68/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.3233 - accuracy: 0.8740 - precision_15: 0.9078 - recall_13: 0.6567 - val_loss: 3.1751 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 69/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2707 - accuracy: 0.8846 - precision_15: 0.9646 - recall_13: 0.6484 - val_loss: 3.0393 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 70/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2348 - accuracy: 0.8952 - precision_15: 0.9987 - recall_13: 0.6599 - val_loss: 2.9836 - val_accuracy: 0.1136 - val_precision_15: 1.0000 - val_recall_13: 0.1136
# Epoch 71/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2499 - accuracy: 0.8883 - precision_15: 0.9713 - recall_13: 0.6561 - val_loss: 3.1266 - val_accuracy: 0.1039 - val_precision_15: 1.0000 - val_recall_13: 0.1039
# Epoch 72/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2312 - accuracy: 0.8957 - precision_15: 0.9925 - recall_13: 0.6655 - val_loss: 2.8204 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 73/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2237 - accuracy: 0.8972 - precision_15: 0.9892 - recall_13: 0.6728 - val_loss: 2.9452 - val_accuracy: 0.0392 - val_precision_15: 1.0000 - val_recall_13: 0.0392
# Epoch 74/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2703 - accuracy: 0.8759 - precision_15: 0.9286 - recall_13: 0.6458 - val_loss: 2.8908 - val_accuracy: 0.1180 - val_precision_15: 1.0000 - val_recall_13: 0.1180
# Epoch 75/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2422 - accuracy: 0.8891 - precision_15: 0.9649 - recall_13: 0.6631 - val_loss: 2.9458 - val_accuracy: 0.0360 - val_precision_15: 1.0000 - val_recall_13: 0.0360
# Epoch 76/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2210 - accuracy: 0.8901 - precision_15: 0.9823 - recall_13: 0.6543 - val_loss: 2.9908 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 77/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2041 - accuracy: 0.8922 - precision_15: 0.9995 - recall_13: 0.6496 - val_loss: 2.8561 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 78/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2132 - accuracy: 0.8962 - precision_15: 0.9908 - recall_13: 0.6684 - val_loss: 2.7757 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 79/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2597 - accuracy: 0.8892 - precision_15: 0.9294 - recall_13: 0.6922 - val_loss: 3.0228 - val_accuracy: 0.0023 - val_precision_15: 1.0000 - val_recall_13: 0.0023
# Epoch 80/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2330 - accuracy: 0.8935 - precision_15: 0.9716 - recall_13: 0.6731 - val_loss: 2.8929 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 81/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2048 - accuracy: 0.8926 - precision_15: 0.9834 - recall_13: 0.6617 - val_loss: 3.0886 - val_accuracy: 0.0065 - val_precision_15: 1.0000 - val_recall_13: 0.0065
# Epoch 82/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2199 - accuracy: 0.8946 - precision_15: 0.9729 - recall_13: 0.6758 - val_loss: 2.8153 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 83/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2017 - accuracy: 0.8985 - precision_15: 0.9758 - recall_13: 0.6869 - val_loss: 3.0762 - val_accuracy: 0.1208 - val_precision_15: 1.0000 - val_recall_13: 0.1208
# Epoch 84/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1889 - accuracy: 0.8976 - precision_15: 0.9930 - recall_13: 0.6717 - val_loss: 2.9815 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 85/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.1927 - accuracy: 0.8918 - precision_15: 0.9838 - recall_13: 0.6587 - val_loss: 2.9309 - val_accuracy: 0.1166 - val_precision_15: 1.0000 - val_recall_13: 0.1166
# Epoch 86/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1886 - accuracy: 0.8974 - precision_15: 0.9892 - recall_13: 0.6734 - val_loss: 2.9180 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 87/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1826 - accuracy: 0.9035 - precision_15: 0.9830 - recall_13: 0.6981 - val_loss: 2.8774 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 88/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2551 - accuracy: 0.8766 - precision_15: 0.9105 - recall_13: 0.6637 - val_loss: 2.9811 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 89/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1638 - accuracy: 0.8972 - precision_15: 0.9978 - recall_13: 0.6670 - val_loss: 3.0634 - val_accuracy: 0.0198 - val_precision_15: 1.0000 - val_recall_13: 0.0198
# Epoch 90/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1737 - accuracy: 0.8964 - precision_15: 0.9858 - recall_13: 0.6725 - val_loss: 2.8550 - val_accuracy: 0.0019 - val_precision_15: 1.0000 - val_recall_13: 0.0019
# Epoch 91/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.2097 - accuracy: 0.8814 - precision_15: 0.9496 - recall_13: 0.6484 - val_loss: 3.1415 - val_accuracy: 0.0497 - val_precision_15: 1.0000 - val_recall_13: 0.0497
# Epoch 92/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1907 - accuracy: 0.8908 - precision_15: 0.9636 - recall_13: 0.6699 - val_loss: 2.9106 - val_accuracy: 0.0099 - val_precision_15: 1.0000 - val_recall_13: 0.0099
# Epoch 93/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1784 - accuracy: 0.8990 - precision_15: 0.9711 - recall_13: 0.6919 - val_loss: 2.8529 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 94/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1568 - accuracy: 0.8954 - precision_15: 0.9900 - recall_13: 0.6664 - val_loss: 2.9367 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 95/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1786 - accuracy: 0.8873 - precision_15: 0.9540 - recall_13: 0.6652 - val_loss: 2.9286 - val_accuracy: 0.0067 - val_precision_15: 1.0000 - val_recall_13: 0.0067
# Epoch 96/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1630 - accuracy: 0.8957 - precision_15: 0.9853 - recall_13: 0.6708 - val_loss: 2.8721 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 97/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1536 - accuracy: 0.8907 - precision_15: 0.9684 - recall_13: 0.6661 - val_loss: 2.9692 - val_accuracy: 0.1389 - val_precision_15: 1.0000 - val_recall_13: 0.1389
# Epoch 98/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1604 - accuracy: 0.9010 - precision_15: 0.9881 - recall_13: 0.6861 - val_loss: 2.7990 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 99/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1614 - accuracy: 0.8927 - precision_15: 0.9616 - recall_13: 0.6778 - val_loss: 3.0276 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 100/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1548 - accuracy: 0.8925 - precision_15: 0.9735 - recall_13: 0.6684 - val_loss: 2.9853 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 101/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1252 - accuracy: 0.9004 - precision_15: 0.9927 - recall_13: 0.6811 - val_loss: 3.0061 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 102/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1347 - accuracy: 0.8981 - precision_15: 0.9884 - recall_13: 0.6764 - val_loss: 2.9969 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 103/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1540 - accuracy: 0.8996 - precision_15: 0.9674 - recall_13: 0.6969 - val_loss: 2.9002 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 104/150
# 56/56 [==============================] - 0s 7ms/step - loss: 1.1569 - accuracy: 0.8950 - precision_15: 0.9678 - recall_13: 0.6811 - val_loss: 2.8376 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 105/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1751 - accuracy: 0.8855 - precision_15: 0.9292 - recall_13: 0.6793 - val_loss: 2.8628 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 106/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1284 - accuracy: 0.8981 - precision_15: 0.9838 - recall_13: 0.6796 - val_loss: 2.8760 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 107/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1106 - accuracy: 0.8960 - precision_15: 0.9934 - recall_13: 0.6661 - val_loss: 3.0396 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 108/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1343 - accuracy: 0.8982 - precision_15: 0.9734 - recall_13: 0.6875 - val_loss: 2.8559 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 109/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1124 - accuracy: 0.9041 - precision_15: 0.9924 - recall_13: 0.6934 - val_loss: 2.8932 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 110/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1211 - accuracy: 0.8894 - precision_15: 0.9698 - recall_13: 0.6608 - val_loss: 2.8632 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 111/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0955 - accuracy: 0.8985 - precision_15: 0.9931 - recall_13: 0.6746 - val_loss: 2.9055 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 112/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0951 - accuracy: 0.9011 - precision_15: 0.9996 - recall_13: 0.6784 - val_loss: 2.7496 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 113/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1493 - accuracy: 0.8861 - precision_15: 0.9492 - recall_13: 0.6649 - val_loss: 3.0148 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 114/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1275 - accuracy: 0.8903 - precision_15: 0.9551 - recall_13: 0.6749 - val_loss: 2.9652 - val_accuracy: 0.1722 - val_precision_15: 1.0000 - val_recall_13: 0.1722
# Epoch 115/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1392 - accuracy: 0.8894 - precision_15: 0.9342 - recall_13: 0.6887 - val_loss: 2.7890 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 116/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0810 - accuracy: 0.8934 - precision_15: 0.9982 - recall_13: 0.6543 - val_loss: 2.8793 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 117/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0875 - accuracy: 0.9054 - precision_15: 0.9950 - recall_13: 0.6958 - val_loss: 2.9830 - val_accuracy: 0.0523 - val_precision_15: 1.0000 - val_recall_13: 0.0523
# Epoch 118/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0672 - accuracy: 0.8992 - precision_15: 0.9991 - recall_13: 0.6725 - val_loss: 2.9067 - val_accuracy: 0.0240 - val_precision_15: 1.0000 - val_recall_13: 0.0240
# Epoch 119/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0778 - accuracy: 0.9040 - precision_15: 0.9953 - recall_13: 0.6908 - val_loss: 2.8704 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 120/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1022 - accuracy: 0.8895 - precision_15: 0.9615 - recall_13: 0.6673 - val_loss: 2.8107 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 121/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0849 - accuracy: 0.9013 - precision_15: 0.9829 - recall_13: 0.6908 - val_loss: 2.9013 - val_accuracy: 0.0133 - val_precision_15: 1.0000 - val_recall_13: 0.0133
# Epoch 122/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0828 - accuracy: 0.8964 - precision_15: 0.9879 - recall_13: 0.6711 - val_loss: 2.9250 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 123/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0843 - accuracy: 0.8905 - precision_15: 0.9656 - recall_13: 0.6675 - val_loss: 2.9685 - val_accuracy: 0.1199 - val_precision_15: 1.0000 - val_recall_13: 0.1199
# Epoch 124/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0920 - accuracy: 0.8992 - precision_15: 0.9704 - recall_13: 0.6931 - val_loss: 2.9024 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 125/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0497 - accuracy: 0.9016 - precision_15: 0.9987 - recall_13: 0.6808 - val_loss: 2.8426 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 126/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0706 - accuracy: 0.9029 - precision_15: 0.9883 - recall_13: 0.6922 - val_loss: 2.8684 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 127/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1128 - accuracy: 0.8790 - precision_15: 0.9233 - recall_13: 0.6614 - val_loss: 2.8621 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 128/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0466 - accuracy: 0.9036 - precision_15: 0.9937 - recall_13: 0.6908 - val_loss: 2.9076 - val_accuracy: 0.0234 - val_precision_15: 1.0000 - val_recall_13: 0.0234
# Epoch 129/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0438 - accuracy: 0.9010 - precision_15: 0.9948 - recall_13: 0.6814 - val_loss: 2.8337 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 130/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0340 - accuracy: 0.8957 - precision_15: 0.9987 - recall_13: 0.6614 - val_loss: 2.9041 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 131/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0341 - accuracy: 0.8989 - precision_15: 0.9983 - recall_13: 0.6723 - val_loss: 2.8813 - val_accuracy: 0.0323 - val_precision_15: 1.0000 - val_recall_13: 0.0323
# Epoch 132/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0330 - accuracy: 0.9026 - precision_15: 0.9957 - recall_13: 0.6861 - val_loss: 2.7982 - val_accuracy: 0.0118 - val_precision_15: 1.0000 - val_recall_13: 0.0118
# Epoch 133/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0374 - accuracy: 0.9034 - precision_15: 0.9974 - recall_13: 0.6875 - val_loss: 2.7944 - val_accuracy: 0.0784 - val_precision_15: 1.0000 - val_recall_13: 0.0784
# Epoch 134/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0321 - accuracy: 0.8994 - precision_15: 0.9948 - recall_13: 0.6761 - val_loss: 2.8779 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 135/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0270 - accuracy: 0.9017 - precision_15: 0.9949 - recall_13: 0.6837 - val_loss: 2.8278 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 136/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0178 - accuracy: 0.9020 - precision_15: 0.9970 - recall_13: 0.6831 - val_loss: 2.7601 - val_accuracy: 0.0131 - val_precision_15: 1.0000 - val_recall_13: 0.0131
# Epoch 137/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0232 - accuracy: 0.9032 - precision_15: 0.9983 - recall_13: 0.6861 - val_loss: 2.7849 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 138/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0145 - accuracy: 0.9041 - precision_15: 0.9987 - recall_13: 0.6890 - val_loss: 2.7320 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 139/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0223 - accuracy: 0.9024 - precision_15: 0.9962 - recall_13: 0.6852 - val_loss: 2.8075 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 140/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0275 - accuracy: 0.8943 - precision_15: 0.9873 - recall_13: 0.6646 - val_loss: 2.8806 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 141/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0251 - accuracy: 0.9025 - precision_15: 0.9920 - recall_13: 0.6884 - val_loss: 2.8059 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 142/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0009 - accuracy: 0.9019 - precision_15: 0.9974 - recall_13: 0.6825 - val_loss: 2.7849 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 143/150
# 56/56 [==============================] - 0s 6ms/step - loss: 1.0035 - accuracy: 0.9024 - precision_15: 0.9953 - recall_13: 0.6858 - val_loss: 2.8259 - val_accuracy: 0.1054 - val_precision_15: 1.0000 - val_recall_13: 0.1054
# Epoch 144/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0077 - accuracy: 0.9017 - precision_15: 0.9932 - recall_13: 0.6849 - val_loss: 2.8430 - val_accuracy: 0.0044 - val_precision_15: 1.0000 - val_recall_13: 0.0044
# Epoch 145/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0128 - accuracy: 0.9042 - precision_15: 0.9871 - recall_13: 0.6975 - val_loss: 2.8378 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 146/150
# 56/56 [==============================] - 0s 5ms/step - loss: 0.9987 - accuracy: 0.9067 - precision_15: 0.9996 - recall_13: 0.6966 - val_loss: 2.8290 - val_accuracy: 2.1079e-04 - val_precision_15: 1.0000 - val_recall_13: 2.1079e-04
# Epoch 147/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0092 - accuracy: 0.9058 - precision_15: 0.9937 - recall_13: 0.6978 - val_loss: 2.9094 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 148/150
# 56/56 [==============================] - 0s 5ms/step - loss: 0.9961 - accuracy: 0.9069 - precision_15: 0.9966 - recall_13: 0.6993 - val_loss: 2.8528 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 149/150
# 56/56 [==============================] - 0s 5ms/step - loss: 1.0155 - accuracy: 0.8980 - precision_15: 0.9675 - recall_13: 0.6914 - val_loss: 2.8342 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 150/150
# 56/56 [==============================] - 0s 5ms/step - loss: 0.9877 - accuracy: 0.9001 - precision_15: 0.9996 - recall_13: 0.6752 - val_loss: 2.8832 - val_accuracy: 0.0000e+00 - val_precision_15: 0.0000e+00 - val_recall_13: 0.0000e+00

# %%
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

fig, ax = plt.subplots(figsize=(10,4))
plt.rcParams.update({'font.size': 14})
plt.plot(range(epochs_num), train_loss, label='Обучающий набор')
plt.plot(range(epochs_num), val_loss, label='Проверочный набор')
plt.legend()
plt.xlabel('Эпоха')
plt.ylabel('Ошибка обучения')


#Saving results
image_name = f'figures/loss_NN.jpg'
# fig.savefig(image_name, format='jpg', dpi=110, bbox_inches='tight', pad_inches = 0.2)

# %% [markdown]
# # Prediction

# %%
# model.evaluate(X_test, y_test)

y_est = model.predict(X_test)   # training = False
y_est = np.reshape(y_est,(y_est.shape[0]))
# y_est = 1-y_est
# Out:
# 78/78 [==============================] - 0s 975us/step

# %%
def plot_roc_curve(fpr,tpr,auc): 
  fig,ax = plt.subplots(figsize=(5,3))
  plt.plot(fpr,tpr) 
  plt.axis([0,1,0,1]) 
  plt.xlabel('False Positive Rate') 
  plt.ylabel('True Positive Rate') 
  plt.title(f'AUC = {auc:2.3f}')
  plt.xlim((-0.03, 1.03))
  plt.ylim((-0.03, 1.03))
  return fig

# y_est = np.squeeze(y_est,axis=2)

auc_func = keras.metrics.AUC(thresholds=np.linspace(0,1.0,20))
auc_func.update_state(y_test, y_est)
AUC = auc_func.result().numpy()

fpr, tpr, thresholds = roc_curve (y_test, y_est, pos_label=1.0)    

effectiveness = tpr -fpr
idx = np.argmax(effectiveness)
best_thrs  = thresholds[idx]


prec_func = keras.metrics.Precision(thresholds=best_thrs)
prec_func.update_state(y_test, y_est)
Prec = prec_func.result().numpy()

recall_func = keras.metrics.Recall(thresholds=best_thrs)
recall_func.update_state(y_test, y_est)
Recall = recall_func.result().numpy()

print(f'AUC = {AUC:2.3f}')
print(f'Prec = {Prec:2.3f}')
print(f'Recall = {Recall:2.3f}')

plt.plot(y_test)
plt.plot(y_est)

fig = plot_roc_curve (fpr, tpr, AUC)

plt.show()
# Saving results
# image_name = 'figures/AUC_keras_NN_2_Layers_40_hidden_units_dropout_5_mfcc_frames.jpg'
# fig.savefig(image_name, format='jpg', dpi=140, bbox_inches='tight', pad_inches = 0.2)
# Out:
# AUC = 1.000
# Prec = 1.000
# Recall = 0.999

# %%
W = model.get_weights()
layer1 = W[0]
print(layer1.shape)

fig,ax = plt.subplots(figsize=(10,4),dpi=80)
plt.subplot(131)
W = np.reshape(layer1[0,:,0],(X.shape[1], X.shape[2]))
plt.pcolor(W,shading='flat',cmap='jet')
# plt.colorbar()
plt.title('w1')

plt.subplot(132)
W = np.reshape(layer1[0,:,1],(X.shape[1], X.shape[2]))
plt.pcolor(W,shading='flat',cmap='jet')
# plt.colorbar()
plt.title('w2')

plt.subplot(133)
W = np.reshape(layer1[0,:,2],(X.shape[1], X.shape[2]))
plt.pcolor(W,shading='flat',cmap='jet')
# plt.colorbar()
plt.title('w3')

plt.subplots_adjust(wspace=0.5)
# Out:
# (1, 5504, 3)
